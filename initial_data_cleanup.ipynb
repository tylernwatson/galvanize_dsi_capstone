# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
nov_28_df = pd.read_json('11-28.json')

# %%
nov_29_df = pd.read_json('11-29.json')

# %%
nov_30_df = pd.read_json('11-30 redo.json')

# %%
nov_30_df_2 = pd.read_json('11-30_2.json')

# %%
nov_30_concat = pd.concat([nov_30_df, nov_30_df_2], ignore_index=True)
nov_30_concat = nov_30_concat.drop_duplicates()
nov_30_concat_df = nov_30_concat.sort_values(by=['timestamp'])

# %%
dec_1_df = pd.read_json('12-1.json')

# %%
dec_2_df = pd.read_json('12-2.json')

# %%
dec_3_df = pd.read_json('12-3.json')

# %%
dec_4_df = pd.read_json('12-4 redo.json')

# %%
dec_4_df_2 = pd.read_json('12-4_2.json')

# %%
dec_4_concat = pd.concat([dec_4_df, dec_4_df_2], ignore_index=True)
dec_4_concat = dec_4_concat.drop_duplicates()
dec_4_concat_df = dec_4_concat.sort_values(by=['timestamp'])

# %%
dec_5_df = pd.read_json('12-5.json')

# %%
dec_6_df = pd.read_json('12-6.json')

# %%
dec_7_df = pd.read_json('12-7.json')

# %%
dec_8_df = pd.read_json('12-8.json')

# %%
dec_8_df_2 = pd.read_json('12-8_2.json')

# %%
dec_8_concat = pd.concat([dec_8_df, dec_8_df_2], ignore_index=True)
dec_8_concat = dec_8_concat.drop_duplicates()
dec_8_concat_df = dec_8_concat.sort_values(by=['timestamp'])

# %%
dec_9_df = pd.read_json('12-9.json')

# %%
dec_9_df_2 = pd.read_json('12-9_2.json')

# %%
dec_9_concat = pd.concat([dec_9_df, dec_9_df_2], ignore_index=True)
dec_9_concat = dec_9_concat.drop_duplicates()
dec_9_concat_df = dec_9_concat.sort_values(by=['timestamp'])

# %%
dec_10_df = pd.read_json('12-10.json')

# %%
dec_11_df = pd.read_json('12-11.json')

# %%
dec_12_df = pd.read_json('12-12.json')

# %%
dec_13_df = pd.read_json('12-13.json')

# %%
dec_14_df = pd.read_json('12-14.json')

# %% [markdown]
# # Create concatenated DataFrame

# %%
mega_df = pd.concat([nov_28_df, nov_29_df, nov_30_concat_df, dec_1_df, dec_2_df, dec_3_df, \
                    dec_4_concat_df, dec_5_df, dec_6_df, dec_7_df, dec_8_concat_df, dec_9_concat_df, \
                    dec_10_df, dec_11_df, dec_12_df, dec_13_df, dec_14_df], ignore_index=True)

# %%
mega_df.describe()
# Out:
#                  id          likes        replies       retweets
# count  4.193430e+05  419343.000000  419343.000000  419343.000000
# mean   9.393097e+17       6.223788       0.206325       4.391949
# std    1.750021e+15     415.162837       9.443255     304.453924
# min    9.352972e+17       0.000000       0.000000       0.000000
# 25%    9.381515e+17       0.000000       0.000000       0.000000
# 50%    9.399272e+17       0.000000       0.000000       0.000000
# 75%    9.409810e+17       1.000000       0.000000       0.000000
# max    9.414578e+17  216270.000000    3694.000000  165604.000000

# %%
mega_df.head()

# %% [markdown]
# # Clean up those Tweets so they are easier to parse

# %% [markdown]
# ## Remove links, emojis, and @s

# %%
mega_df_cleaning = mega_df.copy()
# mega_df_cleaning['links'] = 0
# mega_df_cleaning['emojis'] = 0
# mega_df_cleaning['other_hashtags'] = ''
# mega_df_cleaning['@s'] = 0

# %%
mega_df_cleaning.tail()
# Out:
#                 fullname                  id  likes  replies  retweets  \
# 419338  Danielle Lamoree  941457770016108544      0        0         0
# 419339         Ali Druge  941457771857350656      0        0         0
# 419340            NAPOLI  941457772276744192      1        0         1
# 419341  Thomas Immervoll  941457774407536640      1        0         1
# 419342      Joey O'Brien  941457776362082304      0        0         0
#
#                                                      text           timestamp  \
# 419338  #NetNeutrality https://twitter.com/thereaIbank... 2017-12-14 23:59:58
# 419339  #NetNeutrality is key to free expression, inno... 2017-12-14 23:59:58
# 419340                                     #NetNeutrality 2017-12-14 23:59:59
# 419341  Internet der zwei Geschwindigkeiten. Das endgü... 2017-12-14 23:59:59
# 419342  #NetNeutrality is key to free expression, inno... 2017-12-14 23:59:59
#
#                                               url            user
# 419338  /Babydee_111215/status/941457770016108544  Babydee_111215
# 419339        /alidruge/status/941457771857350657        alidruge
# 419340       /luigi_pzi/status/941457772276744202       luigi_pzi
# 419341      /timmervoll/status/941457774407536640      timmervoll
# 419342       /Joey_OB10/status/941457776362082304       Joey_OB10

# %%
small_slice = mega_df_cleaning[:100]
mega_df_cleaning_2 = mega_df_cleaning.copy()

# %%
for row, text in enumerate(small_slice['text']):
    hashtags = []
    for t in text.lower().split():
#         if t.startswith("http"):
#             mega_df_cleaning['links'][row] = t
#         elif t.startswith("@"):
#             mega_df_cleaning['@s'] = []
#             mega_df_cleaning['@s'][row].append(t)
        if (t.startswith("#")) & (t != '#netneutrality'):
            hashtags.append(t)
    small_slice['other_hashtags'][row] = hashtags
# Out:
# ['#boycottverizon', '#vote', '#register', '#election2018', '#internet', '#money', '#isp', '#titleii', '#freemarket', '#consumers', '#costs', '#advocacy', '#ethics', '#corruption', '#crime', '#publictrust', '#fcc']
# ['#dec14', '#fcc']
# ['#netneutrality!']
# []
# []
# []
# []
# ['#netneutrality.']
# []
# []
# []
# []
# []
# []
# ['#btvcc', '#btvhttps://docs.google.com/document/d/1hw7mko3gg04h9nqutm858lmhr6zdx5uvenvmt80-gey/edit']
# []
# ['#neutralizenet']
# []
# []
# []
# ['#netneutrality.']
# ['#netneutrality?', '#wwwresistpic.twitter.com/yitaqx1e4o']
# ['#petition']
# []
# []
# ['#comcastthrottling', '#bittorrent', '#without', '#cablecompanies', '#phonecompanies', '#carve', '#internet', '#fastandslow']
# ['#inners', '#allinwithchris', '#nodemocracyintheunitedstates', '#bananarepublic', '#riggedsystempic.twitter.com/pfp1wvumgu']
# []
# ['#netneutrality?']
# []
# ['#btvcc', '#btvhttps://twitter.com/channel_online/status/935223250073870338']
# ['#dontletthiscorporatescumtakewhatsourspic.twitter.com/kezmlqqvqp']
# []
# []
# ['#p2', '#tntweeters', '#uslatino', '#resist']
# []
# ['#netneutralityِ']
# []
# []
# []
# []
# ['#co-opwifi']
# []
# ['#resist', '#maga', '#projectveritas', '#pocahontas', '#youracistbastard', '#nativeamerican', '#navajocodetalkers', '#elizabethwarren', '#washingtonpost', '#trumpisawhitesupremacist', '#tellthefcc', '#goptaxscam', '#taxreform', '#roymoore', '#roymoorechildmolesterpic.twitter.com/3ulo5plm89']
# []
# ['#netneutrality,']
# ['#strangerthings', '#facebook.']
# []
# ['#trumprussiaconspiracy', '#goptaxscam', '#paperballotshttps://twitter.com/nowthisnews/status/935312057162858496']
# ['#netneutrality.']
# []
# []
# []
# []
# []
# ['#teaminternet', '#netneutrality.']
# []
# ['#netneutrality,']
# []
# ['#gaming.https://blastawaythegamereview.com/2017/11/27/gamers-net-neutrality-could-hit-you-the-hardest/']
# ['#followthemoney']
# []
# []
# ['#fcc']
# ['#mondaymotivation', '#resist', '#usstrong', '#mmhttps://twitter.com/thenextweb/status/935309284447084544']
# ['#freeinternet', '#netneutralityِ']
# ['#altright', '#factsfirst', '#facisism', '#factsmatter', '#corruptgop', '#roymoorestepdown', '#alabamasenaterace', '#alabama', '#nazisout']
# []
# ['#netneutrality.']
# ['#freethenethttps://twitter.com/comcast/status/933394263689351175']
# []
# ['#taxscambill']
# []
# ['#fuckthefcc']
# ['#netneutrality.']
# ['#savenetneutrality']
# ['#netneutrality.', '#infographic.http://www.businessinsider.com/net-neutrality-portugal-how-american-internet-could-look-fcc-2017-11']
# ['#supportnetneutrality', '#savenetneutrality', '#repostpic.twitter.com/nmdw2m4urb']
# []
# []
# []
# []
# ['#savetheinternet']
# ['#repostpic.twitter.com/jjbshu1k13']
# ['#toolate']
# ['#fcc', '#netneutrality!!']
# ['#netneutralityِ', '#savenetneutrality']
# ['#titleii']
# []
# ['#cleandreamactnow', '#netneutrality.']
# []
# ['#repostpic.twitter.com/18c2jkoqfw']
# []
# []
# []
# ['#filmmaking', '#actors', '#photography', '#musicians']
# []
# []
# []
# ['#overthetarget', '#bombsawayonneutrality', '#maga', '#trumpderangementsyndrome']
# ['#cybermonday', '#fuckcomcast', '#gofccyourself']
# ['#netneutrality!']
# []
# []
# ['#internetfreedom']
# []
# []
# ['#resist', '#theresistancepic.twitter.com/r2m4uevaak']
# []
# ['#netneutrality.', '#raeyve']
# ['#fuckthat']
# ['#overthetarget', '#bombsawayonneutrality', '#maga', '#trumpderangementsyndrome']
# ['#internet', '#colorado', '#netneutraility']
# ['#adhttps://twitter.com/kamalaharris/status/934108339730083840']
# []
# []
# []
# ['#greed', '#monopoly']
# []
# []
# ['#savetheinternetpic.twitter.com/z3qupkjmfo']
# []
# []
# ['#savenetneutrality']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#netneutrality?']
# ['#teaminternet', '#netneutrality.']
# ['#fcc', '#internet', '#petition', '#resist', '#indivisible']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#patriarchialphilanthropy', '#onshoretaxes']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#netneutrality,', '#mediajustice']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['#netneutrality.']
# []
# ['#savenetneutrality']
# []
# []
# []
# []
# ['#browngirlspeaks']
# ['#btvcc']
# []
# ['#netneutrality.']
# []
# []
# []
# []
# ['#environment', '#weather', '#disasters']
# ['#realworld', '#problems', '#memes', '#anonymouspic.twitter.com/5oyk8koghc']
# []
# []
# ['#netneutrality.']
# []
# []
# []
# []
# []
# ['#teaminternet', '#netneutrality.']
# ['#environment', '#weather', '#disasters']
# []
# ['#fcc']
# ['#educate', '#retweet', '#repost', '#awareness', '#banenationpic.twitter.com/41ih8pg7zo']
# []
# []

# %%
import re, string


def get_hashtags(text):
    hashtags = []
    for t in text.lower().split():
#         if t.startswith("http"):
#             mega_df_cleaning['links'][row] = t
#         elif t.startswith("@"):
#             mega_df_cleaning['@s'] = []
#             mega_df_cleaning['@s'][row].append(t)
        if (t.startswith("#")) & (t != '#netneutrality'):
            result = re.findall('#[\w_]+', t)
            for x in result:
                hashtags.append(x)
            
    return hashtags

# %%
get_hashtags("wow i love #fcc's good #tweet.s")
# Out:
# ['#fcc']
# ['#tweet']

# %%
def get_links(text):
    links = []
    for t in text.lower().split():
        if t.startswith("http"):
            links.append(t)
#         elif t.startswith("@"):
#             mega_df_cleaning['@s'] = []
#             mega_df_cleaning['@s'][row].append(t)
    return links

# %%
def get_mentions(text):
    mentions = []
    for t in text.lower().split():
        if t.startswith("@"):
            if t.endswith("'s"):
                t = t[:-2]
            mentions.append(t)
    return mentions

# %%
mega_df_cleaning["other_hashtags"] = mega_df_cleaning["text"].apply(get_hashtags)
# mega_df_cleaning["links"] = mega_df_cleaning["text"].apply(get_links)
# mega_df_cleaning["@s"] = mega_df_cleaning["text"].apply(get_mentions)

# %%
def negative_tweet_grab(other_hashtags):
    hashtag_list = ['#notonetneutrality', '#nonetneutrality', '#maga', '#trumptrain', '#libtard', '#presidenttrump',\
                   '#presidentdonaldtrump', '#makeamericagreatagain', '#draintheswamp', '#deplorables']
    if len(other_hashtags) > 0:
        for hashtag in other_hashtags:
            if hashtag in hashtag_list:
                return 1
        else:
            return 0
    else:
        return 0

# %%
mega_df_cleaning['#NoToNetNeutrality'] = mega_df_cleaning['other_hashtags'].apply(negative_tweet_grab)

# %%
mega_df_cleaning['#NoToNetNeutrality'].value_counts()
# Out:
# 0    418864
# 1       479
# Name: #NoToNetNeutrality, dtype: int64

# %%
mega_df_cleaning
# Out:
#                                                fullname                  id  \
# 0                                      Jake Suellentrop  935297188426649600
# 1                                           Jim McGrath  935297192302059520
# 2                                         Kevin C. Bell  935297193484754944
# 3                                         Matan Karasov  935297194730586112
# 4                                      Robert Greenwald  935297198170009600
# 5                                         Tulsi Gabbard  935297198274830336
# 6                                         Kamala Harris  935297210597691392
# 7                                       Brave New Films  935297212795576320
# 8                          Tis The Season to be Queen 🎄  935297253710946304
# 9                                     Metro News Canada  935297254361124864
# 10                                     Que Pasa Boricua  935297271629058048
# 11                                     Mac User Boricua  935297318185787392
# 12                                               Dobber  935297359784890368
# 13                                 ☕️michael colorge ☕️  935297368005791744
# 14                                         A Sea Change  935297371940016128
# 15                                                  Rys  935297407432011776
# 16                                         Shelby Shoup  935297411043483648
# 17                                    Waldemar Santiago  935297413794926592
# 419336  [https://cards.twitter.com/cards/18ce54j487s/5...
# 419337                                                 []
# 419338  [https://twitter.com/thereaibanksy/status/9409...
# 419339  [https://cards.twitter.com/cards/18ce54j487s/5...
# 419340                                                 []
# 419341           [http://orf.at/stories/2418930/2418931/]
# 419342  [https://cards.twitter.com/cards/18ce54j487s/5...
#
#                                          @s  #NoToNetNeutrality
# 0                          [@senpatroberts]                   0
# 1                                        []                   0
# 2                                        []                   0
# 3                                    [@fcc]                   0
# 4                                        []                   0
# 5                                        []                   0
# 6                                        []                   0
# 7                                        []                   0
# 8                                        []                   0
# 9                                        []                   0
# 10         [@theintercept, @quepasaboricua]                   0
# 11         [@theintercept, @quepasaboricua]                   0
# 12        [@realdonaldtrump, @jeffsessions]                   0
# 13                                       []                   0
# 14                       [@fcc, @freepress]                   0
# 15                               [@verizon]                   0
# 16                                       []                   0
# 17         [@theintercept, @quepasaboricua]                   0
# 18                                       []                   0
# 19                                       []                   0
# 20                                [@moveon]                   0
# 21                                       []                   0
# 22                                       []                   0
# 23                                       []                   0
# 24                                       []                   0
# 25                                       []                   0
# 26                      [@fcc, @ajitpaifcc]                   0
# 27                                       []                   0
# 28                                       []                   0
# 29                                       []                   0
# ...                                     ...                 ...
# 419313                                   []                   0
# 419314                                   []                   0
# 419315                           [@twitter]                   0
# 419316                                   []                   0
# 419317                               [@fcc]                   0
# 419318  [@senatortimscott, @linseygrahamsc]                   0
# 419319                            [@change]                   0
# 419320                                   []                   0
# 419321                                   []                   0
# 419322                                   []                   0
# 419323                               [@fcc]                   0
# 419324                                   []                   0
# 419325                                   []                   0
# 419326                                   []                   0
# 419327                                   []                   0
# 419328                               [@fcc]                   0
# 419329                                   []                   0
# 419330                                   []                   0
# 419331                                   []                   0
# 419332                                   []                   0
# 419333                                   []                   0
# 419334                               [@fcc]                   0
# 419335                                   []                   0
# 419336                                   []                   0
# 419337                           [@comcast]                   0
# 419338                                   []                   0
# 419339                                   []                   0
# 419340                                   []                   0
# 419341                                   []                   0
# 419342                                   []                   0
#
# [419343 rows x 13 columns]

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import numpy as np
import re

stop_words = set(stopwords.words('english'))
tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)

def clean_text(dataframe):
    for row, text in enumerate(dataframe['text']):
        filtered_sentence = []
        tokens = tknzr.tokenize(' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).split()).lower())
        for w in tokens:
            if w not in stop_words:
                filtered_sentence.append(w)
        small_slice['cleaned_text'][row] = filtered_sentence

# %%
from collections import Counter
hashtags = Counter()

for items in mega_df_cleaning['other_hashtags']:
    if len(items) != 0:
        for item in items:
            hashtags[item] += 1

# %%
hashtags.most_common()
# Out:
# [('#netneutrality', 91039),
#  ('#stopthefcc', 83231),
#  ('#breaktheinternet', 40388),
#  ('#savenetneutrality', 6119),
#  ('#fcc', 4284),
#  ('#savetheinternet', 2496),
#  ('#goptaxscam', 1726),
#  ('#internet', 1675),
#  ('#resist', 1317),
#  ('#battleforthenet', 1001),
#  ('#ajitpai', 893),
#  ('#bitcoin', 834),
#  ('#अ', 834),
#  ('#netneutraility', 818),
#  ('#taxscambill', 757),
#  ('#blockchain', 757),
#  ('#savenetneutralityhttps', 743),
#  ('#ai', 733),
#  ('#fintech', 722),
#  ('#reprofreedom', 700),
#  ('#bigdata', 678),
#  ('#teaminternet', 672),
#  ('#machinelearning', 663),
#  ('#artificialintelligence', 662),
#  ('#growthhacking', 662),
#  ('#industry40', 657),
#  ('#deeplearning', 657),
#  ('#trump', 656),
#  ('#behavioraleconomics', 653),
#  ('#gmofreehawaii', 653),
#  ('#aloha', 653),
#  ('#hawaii', 652),
#  ('#surf', 652),
#  ('#eddiewouldgo', 651),
#  ('#iot', 650),
#  ('#healthtech', 628),
#  ('#theresistance', 621),
#  ('#crowdfunding', 612),
#  ('#chemtrails', 579),
#  ('#verizon', 534),
#  ('#savethenet', 518),
#  ('#trumprussia', 510),
#  ('#trumprussiaconspiracy', 485),
#  ('#titleii', 476),
#  ('#goptaxscamhttps', 453),
#  ('#worldfortheweb', 451),
#  ('#tech', 449),
#  ('#openinternet', 445),
#  ('#maga', 421),
#  ('#comcast', 390),
#  ('#socialmediapic', 382),
#  ('#taxscam', 368),
#  ('#internetfreedom', 344),
#  ('#congress', 304),
#  ('#freespeech', 298),
#  ('#freedom', 297),
#  ('#nomoore', 273),
#  ('#ripinternet', 270),
#  ('#substratum', 267),
#  ('#savenetneutralitypic', 258),
#  ('#gofccyourself', 255),
#  ('#gop', 255),
#  ('#usgeneralstrike', 255),
#  ('#resigntrump', 252),
#  ('#resistance', 251),
#  ('#metoo', 250),
#  ('#stopthefccpic', 246),
#  ('#netnuetrality', 245),
#  ('#trumpconspired', 245),
#  ('#socialmedia', 243),
#  ('#chip', 234),
#  ('#stopthefcchttps', 231),
#  ('#wednesdaywisdom', 226),
#  ('#tuesdaythoughts', 225),
#  ('#taxreform', 224),
#  ('#puertorico', 223),
#  ('#taxbill', 206),
#  ('#twitter', 205),
#  ('#usa', 204),
#  ('#democracy', 197),
#  ('#news', 195),
#  ('#savethenetbot', 184),
#  ('#cryptocurrency', 184),
#  ('#breaktheinternethttps', 184),
#  ('#healthcare', 178),
#  ('#impeachtrump', 174),
#  ('#truth', 174),
#  ('#technology', 173),
#  ('#donotgogentle', 173),
#  ('#education', 172),
#  ('#anonymous', 169),
#  ('#fcchttps', 163),
#  ('#isp', 154),
#  ('#verizonprotests', 154),
#  ('#christmas', 151),
#  ('#censorship', 149),
#  ('#savetheinternethttps', 147),
#  ('#internetneutrality', 146),
#  ('#freedomofspeech', 144),
#  ('#trai', 143),
#  ('#thelastjedi', 143),
#  ('#resisthttps', 142),
#  ('#trumptaxscam', 141),
#  ('#boycottverizon', 140),
#  ('#america', 139),
#  ('#smallbusiness', 137),
#  ('#youtube', 137),
#  ('#politics', 137),
#  ('#breaking', 136),
#  ('#sub', 136),
#  ('#startups', 136),
#  ('#daca', 134),
#  ('#business', 133),
#  ('#corruption', 131),
#  ('#internetpic', 130),
#  ('#innovation', 129),
#  ('#privacy', 129),
#  ('#cybermonday', 128),
#  ('#breaktheinternetpic', 128),
#  ('#savetheinternetpic', 127),
#  ('#fakenews', 126),
#  ('#paperballots', 126),
#  ('#goptaxplan', 126),
#  ('#thetruthcommunity', 125),
#  ('#givingtuesday', 124),
#  ('#truthers', 122),
#  ('#google', 117),
#  ('#savenetneutraility', 116),
#  ('#freepress', 114),
#  ('#india', 114),
#  ('#freeinternet', 113),
#  ('#cdnpoli', 112),
#  ('#broadband', 111),
#  ('#stopthefcchttp', 109),
#  ('#podcast', 107),
#  ('#propelling', 107),
#  ('#fccpic', 106),
#  ('#goptaxbill', 106),
#  ('#facebook', 105),
#  ('#firepai', 103),
#  ('#poll', 102),
#  ('#telecom', 102),
#  ('#netflix', 102),
#  ('#reddit', 101),
#  ('#roymoore', 98),
#  ('#tcot', 97),
#  ('#ges2017', 97),
#  ('#rt', 97),
#  ('#protest', 96),
#  ('#wethepeople', 96),
#  ('#thursdaythoughts', 96),
#  ('#altcoin', 95),
#  ('#aca', 95),
#  ('#vpn', 95),
#  ('#net', 95),
#  ('#hyderabadmetro', 94),
#  ('#trumpresign', 92),
#  ('#cybermondayhttps', 92),
#  ('#fireproofmuellerhttps', 92),
#  ('#netneutality', 91),
#  ('#government', 91),
#  ('#blacklivesmatter', 90),
#  ('#noban', 90),
#  ('#republicans', 89),
#  ('#helpnetneutrality', 89),
#  ('#tsunamicup', 88),
#  ('#newprofilepic', 87),
#  ('#fbr', 86),
#  ('#crypto', 85),
#  ('#att', 84),
#  ('#vote', 84),
#  ('#keepnetneutrality', 84),
#  ('#climatechange', 83),
#  ('#democrats', 81),
#  ('#isps', 80),
#  ('#memes', 79),
#  ('#hr4585', 78),
#  ('#edtech', 77),
#  ('#russia', 76),
#  ('#technews', 76),
#  ('#electiontransparency', 76),
#  ('#mondaymotivation', 75),
#  ('#protectnetneutrality', 74),
#  ('#socialmediahttps', 74),
#  ('#fuckthefcc', 73),
#  ('#indivisible', 73),
#  ('#firstamendment', 73),
#  ('#smallbiz', 73),
#  ('#amazon', 72),
#  ('#cybersecurity', 72),
#  ('#media', 72),
#  ('#gujaratbolezee', 72),
#  ('#meme', 72),
#  ('#electiontransparencyhttps', 71),
#  ('#shahongujaratpolls', 71),
#  ('#theresistancehttps', 70),
#  ('#us', 70),
#  ('#pressfreedom', 70),
#  ('#ifunny', 69),
#  ('#cfpb', 69),
#  ('#obama', 69),
#  ('#battleforthenethttps', 69),
#  ('#canada', 68),
#  ('#voteblue', 68),
#  ('#lol', 68),
#  ('#k12', 68),
#  ('#free', 67),
#  ('#unleashthenet', 67),
#  ('#btc', 67),
#  ('#marketing', 67),
#  ('#breaktheinternethttp', 67),
#  ('#p2', 66),
#  ('#ftc', 66),
#  ('#fireajitpai', 65),
#  ('#resistpic', 65),
#  ('#shakti', 65),
#  ('#northkorea', 65),
#  ('#alabamasenateelection', 65),
#  ('#globalentrepreneurshipsummit', 64),
#  ('#for_live', 64),
#  ('#netneutrailitypic', 64),
#  ('#notonepenny', 63),
#  ('#funny', 63),
#  ('#guncontrolnowhttps', 63),
#  ('#amjoy', 63),
#  ('#fridayfeeling', 63),
#  ('#infosec', 62),
#  ('#verizonprotest', 62),
#  ('#infrastructure', 62),
#  ('#digital', 61),
#  ('#dougjones', 61),
#  ('#neutrality', 60),
#  ('#blackwomen', 60),
#  ('#web', 59),
#  ('#cleandreamact', 59),
#  ('#impeachpencefirst', 59),
#  ('#dumptrumptaxscam', 59),
#  ('#muellertime', 58),
#  ('#fuckajitpai', 58),
#  ('#republican', 58),
#  ('#love', 58),
#  ('#startup', 58),
#  ('#thankyoualabama', 58),
#  ('#supportnetneutrality', 57),
#  ('#dougjonesforsenate', 57),
#  ('#notmypresident', 57),
#  ('#alabama', 56),
#  ('#russiagate', 56),
#  ('#americans', 56),
#  ('#roymoorechildmolester', 55),
#  ('#msnbc', 55),
#  ('#oneplus5tsale', 55),
#  ('#taxbillscam', 55),
#  ('#defendnetneutrality', 54),
#  ('#savenetneutralityhttp', 54),
#  ('#rage', 54),
#  ('#twitch', 54),
#  ('#dreamactnow', 54),
#  ('#seattle', 53),
#  ('#humanright', 53),
#  ('#netneutralty', 53),
#  ('#rageagainstthedyingofthelight', 52),
#  ('#tytlive', 52),
#  ('#trumpsexualpredator', 51),
#  ('#humanrights', 51),
#  ('#resistanceunited', 51),
#  ('#starwars', 51),
#  ('#trumptrain', 50),
#  ('#occupy', 50),
#  ('#theinternet', 50),
#  ('#medicare', 50),
#  ('#law', 49),
#  ('#1', 49),
#  ('#smallbusinesses', 49),
#  ('#foxnews', 49),
#  ('#giveaway', 49),
#  ('#donaldtrump', 48),
#  ('#potus', 48),
#  ('#retweet', 48),
#  ('#data', 48),
#  ('#treason', 48),
#  ('#netneutrailityhttps', 48),
#  ('#digitaldivide', 48),
#  ('#digitalmarketing', 48),
#  ('#impeachtrumpnow', 47),
#  ('#strangerthings', 47),
#  ('#greed', 47),
#  ('#mueller', 47),
#  ('#killthebill', 47),
#  ('#wakeup', 47),
#  ('#cryptocurrencies', 47),
#  ('#votedougjones', 47),
#  ('#save', 46),
#  ('#medicareforall', 46),
#  ('#internethttps', 46),
#  ('#flynn', 46),
#  ('#letsroll', 46),
#  ('#petition', 45),
#  ('#gaming', 45),
#  ('#alabamasenaterace', 45),
#  ('#repost', 45),
#  ('#uspoli', 45),
#  ('#eff', 45),
#  ('#fcclive', 45),
#  ('#freethenet', 45),
#  ('#feminism', 45),
#  ('#sundaymorning', 45),
#  ('#goldenglobes', 45),
#  ('#cnn', 44),
#  ('#crtc', 44),
#  ('#music', 44),
#  ('#environment', 44),
#  ('#battleforthenetpic', 44),
#  ('#nyc', 44),
#  ('#voteno', 44),
#  ('#defendourconstitution', 44),
#  ('#help', 43),
#  ('#florida', 43),
#  ('#pjnet', 43),
#  ('#dumptrump', 43),
#  ('#chicago', 43),
#  ('#manetneutrality', 43),
#  ('#security', 42),
#  ('#edchat', 42),
#  ('#hyderabadmetrorail', 42),
#  ('#bluewave', 42),
#  ('#jerusalem', 42),
#  ('#rickandmorty', 42),
#  ('#onlinedemocracy', 41),
#  ('#ajitpaifcc', 41),
#  ('#periscope', 41),
#  ('#autism', 41),
#  ('#protestverizon', 41),
#  ('#protestcomcast', 41),
#  ('#omarosa', 41),
#  ('#freemarket', 40),
#  ('#important', 40),
#  ('#gofccyourselfpic', 40),
#  ('#memesdaily', 40),
#  ('#resistbot', 39),
#  ('#millennials', 39),
#  ('#american', 39),
#  ('#aclu', 39),
#  ('#removepai', 39),
#  ('#lmfao', 39),
#  ('#sagawards', 39),
#  ('#standupfightback', 38),
#  ('#willofthepeople', 38),
#  ('#brexit', 38),
#  ('#entrepreneurs', 38),
#  ('#eu', 38),
#  ('#senate', 38),
#  ('#newyork', 38),
#  ('#goparepervs', 38),
#  ('#fight', 38),
#  ('#pai', 38),
#  ('#destroydickdecember', 38),
#  ('#goodreasonstobeangry', 38),
#  ('#digitalcivilrights', 38),
#  ('#ajitpaihttps', 37),
#  ('#capitalism', 37),
#  ('#telecoms', 37),
#  ('#draintheswamp', 37),
#  ('#votethemout', 37),
#  ('#staywoke', 37),
#  ('#qanon', 37),
#  ('#repeal', 37),
#  ('#protests', 37),
#  ('#bearsears', 37),
#  ('#idubbbzpic', 37),
#  ('#uniteblue', 36),
#  ('#ग', 36),
#  ('#dreamact', 36),
#  ('#at', 36),
#  ('#dc', 36),
#  ('#persist', 36),
#  ('#civilrights', 36),
#  ('#stopthevote', 36),
#  ('#firecongresspic', 36),
#  ('#speakfreely', 35),
#  ('#economy', 35),
#  ('#monsanto', 35),
#  ('#1stamendment', 35),
#  ('#netnutrality', 35),
#  ('#dreamers', 35),
#  ('#soorma', 35),
#  ('#ad', 35),
#  ('#donotgogentleintothatgoodnight', 35),
#  ('#apple', 35),
#  ('#pocahontas', 34),
#  ('#soros', 34),
#  ('#magahttps', 34),
#  ('#cable', 34),
#  ('#socialsecurity', 34),
#  ('#internetfreedomhttps', 34),
#  ('#access', 34),
#  ('#lgbtq', 34),
#  ('#obamacare', 33),
#  ('#money', 33),
#  ('#gabfam', 33),
#  ('#gamers', 33),
#  ('#lies', 33),
#  ('#saturdaymorning', 33),
#  ('#consumers', 32),
#  ('#colorado', 32),
#  ('#breakingnews', 32),
#  ('#johnoliver', 32),
#  ('#shameonyou', 32),
#  ('#savethenethttps', 32),
#  ('#democrat', 32),
#  ('#podernfamily', 32),
#  ('#netzneutralität', 32),
#  ('#corrupt', 32),
#  ('#entrepreneur', 32),
#  ('#stopfcc', 32),
#  ('#crowdfundin', 32),
#  ('#ratify28', 32),
#  ('#xmr', 31),
#  ('#monopoly', 31),
#  ('#liberty', 31),
#  ('#fraud', 31),
#  ('#ethereum', 31),
#  ('#अन', 31),
#  ('#म', 31),
#  ('#bots', 31),
#  ('#freeinternethttps', 31),
#  ('#siliconvalley', 31),
#  ('#nwo', 31),
#  ('#revolution', 31),
#  ('#teaminternetpic', 31),
#  ('#iamtheresistance', 31),
#  ('#corporations', 30),
#  ('#1a', 30),
#  ('#streaming', 30),
#  ('#veterans', 30),
#  ('#seo', 30),
#  ('#wtf', 30),
#  ('#savethenetpic', 30),
#  ('#science', 30),
#  ('#alsen', 30),
#  ('#sellout', 30),
#  ('#impeached', 30),
#  ('#fascism', 30),
#  ('#boston', 30),
#  ('#writeahappystoryin4words', 30),
#  ('#paradisepapers', 29),
#  ('#highered', 29),
#  ('#scotus', 29),
#  ('#grammys', 29),
#  ('#equality', 29),
#  ('#demforce', 29),
#  ('#engage', 29),
#  ('#followthewhiterabbit', 29),
#  ('#wisconsin', 29),
#  ('#womensrights', 29),
#  ('#california', 29),
#  ('#policy', 29),
#  ('#tiosus', 29),
#  ('#neoliberalism', 29),
#  ('#monero', 29),
#  ('#traitor', 28),
#  ('#video', 28),
#  ('#taxreformbill', 28),
#  ('#activism', 28),
#  ('#blacktwitter', 28),
#  ('#constitution', 28),
#  ('#freetheinternet', 28),
#  ('#bernie2020', 28),
#  ('#fuckpai', 28),
#  ('#traitortrump', 28),
#  ('#fccincy', 28),
#  ('#insist', 28),
#  ('#dreamactnowhttp', 28),
#  ('#5g', 27),
#  ('#internetofthings', 27),
#  ('#support', 27),
#  ('#freeandopeninternet', 27),
#  ('#openinternethttps', 27),
#  ('#fighton', 27),
#  ('#maddow', 27),
#  ('#guncontrol', 27),
#  ('#nn', 27),
#  ('#trending', 27),
#  ('#goptaxscambill', 27),
#  ('#delaythevote', 27),
#  ('#protectmueller', 27),
#  ('#boycottcomcast', 26),
#  ('#ajitpaipic', 26),
#  ('#gofccyourselfhttps', 26),
#  ('#keeptheinternetfree', 26),
#  ('#libraries', 26),
#  ('#taxdebate', 26),
#  ('#mattlauer', 26),
#  ('#withoutnetneutrality', 26),
#  ('#nips2017', 26),
#  ('#ripinternethttps', 26),
#  ('#thecakeisalie', 26),
#  ('#beheard', 25),
#  ('#future', 25),
#  ('#btvcc', 25),
#  ('#progressives', 25),
#  ('#donotgogentlehttps', 25),
#  ('#history', 25),
#  ('#infosecpic', 25),
#  ('#win', 25),
#  ('#parisagreement', 25),
#  ('#yemen', 25),
#  ('#art', 25),
#  ('#etsy', 25),
#  ('#iphone', 25),
#  ('#taxes', 25),
#  ('#share', 25),
#  ('#putin', 25),
#  ('#techpic', 25),
#  ('#takeaction', 25),
#  ('#calltoaction', 25),
#  ('#wednesdaywisdompic', 25),
#  ('#netaccess', 25),
#  ('#tbt', 25),
#  ('#dotherightthing', 25),
#  ('#telehealth', 25),
#  ('#bluewave2018', 25),
#  ('#humanrightsday', 25),
#  ('#keatonjones', 25),
#  ('#mybattlecrywouldbe', 25),
#  ('#technewspic', 24),
#  ('#endnetneutrality', 24),
#  ('#blm', 24),
#  ('#competition', 24),
#  ('#women', 24),
#  ('#information', 24),
#  ('#timeout', 24),
#  ('#nodapl', 24),
#  ('#fightfortheftrpic', 24),
#  ('#savetheinternethttp', 24),
#  ('#ceo', 24),
#  ('#entrepreneurship', 24),
#  ('#letsfootball', 24),
#  ('#saveourinternet', 24),
#  ('#texas', 24),
#  ('#panamapapers', 24),
#  ('#travelban', 24),
#  ('#freepeterdouche', 24),
#  ('#starwarsthelastjedi', 24),
#  ('#keaton', 24),
#  ('#fundchipnow', 24),
#  ('#journalism', 23),
#  ('#ccot', 23),
#  ('#citizensunited', 23),
#  ('#boycott', 23),
#  ('#sad', 23),
#  ('#feedly', 23),
#  ('#speakout', 23),
#  ('#strongertogether', 23),
#  ('#inners', 23),
#  ('#wakeupamerica', 23),
#  ('#americanpeople', 23),
#  ('#senators', 23),
#  ('#instagram', 23),
#  ('#wired', 23),
#  ('#bilderberg', 23),
#  ('#fcchttp', 23),
#  ('#teaminternethttps', 23),
#  ('#btcusd', 23),
#  ('#netneutralityprotests', 23),
#  ('#trumpsasexualpredatorhttps', 23),
#  ('#books', 22),
#  ('#trumpsexprobe', 22),
#  ('#nonetneutrality', 22),
#  ('#ethics', 22),
#  ('#washington', 22),
#  ('#neutralidaddelared', 22),
#  ('#propaganda', 22),
#  ('#fightback', 22),
#  ('#speedtest', 22),
#  ('#modiints', 22),
#  ('#health', 22),
#  ('#zerorating', 22),
#  ('#regulation', 22),
#  ('#online', 22),
#  ('#taxplan', 22),
#  ('#stop', 22),
#  ('#nowplaying', 22),
#  ('#progressive', 22),
#  ('#litecoin', 22),
#  ('#stem', 22),
#  ('#europe', 22),
#  ('#happyhanukkah', 22),
#  ('#conservatives', 21),
#  ('#treasonisdeath', 21),
#  ('#libyaslavetrade', 21),
#  ('#trumprussiahttps', 21),
#  ('#supportsmallstreamers', 21),
#  ('#fucktrump', 21),
#  ('#unitedstates', 21),
#  ('#impeach', 21),
#  ('#btv', 21),
#  ('#students', 21),
#  ('#protectthenet', 21),
#  ('#medicaid', 21),
#  ('#gamedev', 21),
#  ('#stopajitpai', 21),
#  ('#rights', 21),
#  ('#wifi', 21),
#  ('#muslimban', 21),
#  ('#change', 21),
#  ('#ourrevolution', 21),
#  ('#impeach45', 21),
#  ('#china', 21),
#  ('#oregon', 21),
#  ('#m4a', 21),
#  ('#solidarity', 21),
#  ('#vimeo', 21),
#  ('#stopcensorship', 21),
#  ('#subcommtech', 21),
#  ('#morningjoe', 21),
#  ('#politicspic', 21),
#  ('#plannedparenthood', 21),
#  ('#telemedicine', 21),
#  ('#december1st', 21),
#  ('#saturdaynight', 21),
#  ('#resisthttp', 21),
#  ('#wearelegion', 21),
#  ('#fed', 21),
#  ('#agenda21', 21),
#  ('#mythreecelebdinnerwouldbe', 21),
#  ('#resign', 20),
#  ('#beijing', 20),
#  ('#crisisonearthx', 20),
#  ('#ea', 20),
#  ('#dems', 20),
#  ('#travel', 20),
#  ('#content', 20),
#  ('#omaha', 20),
#  ('#mobile', 20),
#  ('#left', 20),
#  ('#geeksresist', 20),
#  ('#tv', 20),
#  ('#realestate', 20),
#  ('#urgent', 20),
#  ('#unhackthevote', 20),
#  ('#fbi', 20),
#  ('#fightfortheftr', 20),
#  ('#usapic', 20),
#  ('#consumerprotection', 20),
#  ('#creepingfascism', 20),
#  ('#np', 20),
#  ('#revolt', 20),
#  ('#fireproofmueller', 20),
#  ('#powerofthepeople', 20),
#  ('#overturncitizensunited', 20),
#  ('#trumprussiaconspiracyhttps', 20),
#  ('#deletetheelite', 20),
#  ('#anonops', 20),
#  ('#resistanceisimportant', 20),
#  ('#tumblr', 19),
#  ('#youtuber', 19),
#  ('#aspca', 19),
#  ('#charitycontent', 19),
#  ('#newsで妄想', 19),
#  ('#archaeology', 19),
#  ('#famoushistory', 19),
#  ('#pekingman', 19),
#  ('#greece', 19),
#  ('#supportcharity', 19),
#  ('#philanthropist', 19),
#  ('#trumprussiacollusion', 19),
#  ('#icymi', 19),
#  ('#netneutralitymatters', 19),
#  ('#riseup', 19),
#  ('#occupai', 19),
#  ('#doyourjob', 19),
#  ('#floribamashore', 19),
#  ('#jerseyshore', 19),
#  ('#regulations', 19),
#  ('#freedomofthepress', 19),
#  ('#nafta', 19),
#  ('#corporategreed', 19),
#  ('#cdnpolihttps', 19),
#  ('#putinspuppet', 19),
#  ('#areallconservativeschildmolesters', 19),
#  ('#doconservativeshatechildren', 19),
#  ('#doconservativeshatenetneutrality', 19),
#  ('#ilovewikipedia', 19),
#  ('#telecomprom', 19),
#  ('#grabyourwallet', 19),
#  ('#hannity', 19),
#  ('#army', 19),
#  ('#bts', 19),
#  ('#nationalcookieday', 19),
#  ('#nomuslimbanever', 19),
#  ('#ripinternetpic', 19),
#  ('#legalizedemocracy', 19),
#  ('#hacktheelite', 19),
#  ('#rothschilds', 19),
#  ('#imf', 19),
#  ('#anofamily', 19),
#  ('#revolution2018', 19),
#  ('#callyourcongresspeople', 19),
#  ('#fightonpic', 19),
#  ('#pioneers4nn', 19),
#  ('#civilwar2017', 18),
#  ('#marchoncongress', 18),
#  ('#notaxcuts', 18),
#  ('#fb', 18),
#  ('#voiceofthepeople', 18),
#  ('#corruptgop', 18),
#  ('#puertoricorelief', 18),
#  ('#porn', 18),
#  ('#callcongress', 18),
#  ('#comcastlies', 18),
#  ('#takeaknee', 18),
#  ('#substratumhttps', 18),
#  ('#thewalkingdead', 18),
#  ('#blog', 18),
#  ('#nobannowallnoraids', 18),
#  ('#censor', 18),
#  ('#nfl', 18),
#  ('#trumplies', 18),
#  ('#aaronswartz', 18),
#  ('#internetfreedompic', 18),
#  ('#2', 18),
#  ('#fightforthefuture', 18),
#  ('#god', 18),
#  ('#radio', 18),
#  ('#eth', 18),
#  ('#fbrhttps', 18),
#  ('#soundcloud', 18),
#  ('#y2k', 18),
#  ('#call', 18),
#  ('#title2', 18),
#  ('#corporatism', 18),
#  ('#shame', 18),
#  ('#culture', 18),
#  ('#altcoins', 18),
#  ('#howto', 18),
#  ('#artists', 18),
#  ('#jurassicworld', 18),
#  ('#bell', 18),
#  ('#thomasfire', 18),
#  ('#rebootliberty', 17),
#  ('#tuesdaythoughtspic', 17),
#  ('#cdntech', 17),
#  ('#governmentcorruption', 17),
#  ('#deathofdemocracy', 17),
#  ('#opposition', 17),
#  ('#activismpic', 17),
#  ('#blackfriday', 17),
#  ('#libertarian', 17),
#  ('#nationalparks', 17),
#  ('#nobannowall', 17),
#  ('#network', 17),
#  ('#internetforall', 17),
#  ('#people', 17),
#  ('#msm', 17),
#  ('#comcasthttps', 17),
#  ('#hulu', 17),
#  ('#leadership', 17),
#  ('#epa', 17),
#  ('#smb', 17),
#  ('#tax', 17),
#  ('#tmobile', 17),
#  ('#nonprofits', 17),
#  ('#hypocrisy', 17),
#  ('#speakup', 17),
#  ('#conspiracy', 17),
#  ('#newshttps', 17),
#  ('#norepeal', 17),
#  ('#life', 17),
#  ('#subdccp', 17),
#  ('#awsreinvent', 17),
#  ('#korybaker', 17),
#  ('#3', 17),
#  ('#worldaidsday', 17),
#  ('#thisisnotnormal', 17),
#  ('#delayfccvote', 17),
#  ('#opvendetta', 17),
#  ('#resignpaihttps', 17),
#  ('#takingseatsback', 16),
#  ('#goptaxscampic', 16),
#  ('#altright', 16),
#  ('#corporate', 16),
#  ('#throttling', 16),
#  ('#design', 16),
#  ('#uk', 16),
#  ('#smm', 16),
#  ('#dueprocess', 16),
#  ('#jobs', 16),
#  ('#bipartisan', 16),
#  ('#ajit', 16),
#  ('#tuesdaymotivation', 16),
#  ('#lifeline', 16),
#  ('#roymoorechildmolestor', 16),
#  ('#opinion', 16),
#  ('#ott', 16),
#  ('#puertoricohttps', 16),
#  ('#open', 16),
#  ('#freedomofexpression', 16),
#  ('#ajitpaisucks', 16),
#  ('#resisttrump', 16),
#  ('#facepalm', 16),
#  ('#mtpol', 16),
#  ('#wednesdaywisdomhttps', 16),
#  ('#ny', 16),
#  ('#freedomhttps', 16),
#  ('#lgbt', 16),
#  ('#firepaihttps', 16),
#  ('#anons', 16),
#  ('#episode23', 16),
#  ('#jimharbaugh', 16),
#  ('#arizona', 16),
#  ('#tucker', 16),
#  ('#rulesofengagement', 16),
#  ('#supermoon', 16),
#  ('#followbackresistancepic', 16),
#  ('#gcl', 16),
#  ('#webserieschat', 16),
#  ('#kochbrothers', 15),
#  ('#election2018', 15),
#  ('#followthemoney', 15),
#  ('#cleandreamactnow', 15),
#  ('#musicians', 15),
#  ('#theresistancepic', 15),
#  ('#gamer', 15),
#  ('#fake', 15),
#  ('#25thamendmentnow', 15),
#  ('#ohio', 15),
#  ('#ecommerce', 15),
#  ('#edtechafterdark', 15),
#  ('#fukushima', 15),
#  ('#pailies', 15),
#  ('#protect', 15),
#  ('#votingrights', 15),
#  ('#nra', 15),
#  ('#portugal', 15),
#  ('#1984', 15),
#  ('#netfreedom', 15),
#  ('#it', 15),
#  ('#immigration', 15),
#  ('#antitrust', 15),
#  ('#wiunion', 15),
#  ('#spectrum', 15),
#  ('#taxscambillhttps', 15),
#  ('#comedy', 15),
#  ('#facts', 15),
#  ('#cripthevote', 15),
#  ('#copolitics', 15),
#  ('#votersuppression', 15),
#  ('#netneutralityday', 15),
#  ('#thread', 15),
#  ('#netnuetralityhttps', 15),
#  ('#antifa', 15),
#  ('#dash', 15),
#  ('#equal', 15),
#  ('#notaxscam', 15),
#  ('#listen', 15),
#  ('#sexualharassment', 15),
#  ('#timewarner', 15),
#  ('#impeachnow', 15),
#  ('#flynnflipped', 15),
#  ('#greedoverpeople', 15),
#  ('#miami', 15),
#  ('#substrate', 15),
#  ('#bitcoin10k', 15),
#  ('#amplify', 15),
#  ('#timepoy', 15),
#  ('#tyranny', 15),
#  ('#readyplayerone', 15),
#  ('#verizonprotestspic', 15),
#  ('#amplifyhttps', 15),
#  ('#alabamasenate', 15),
#  ('#csgoblessed', 15),
#  ('#savenetneutrailityhttps', 14),
#  ('#callyourreps', 14),
#  ('#edtechchat', 14),
#  ('#freedomofinformation', 14),
#  ('#needtoimpeach', 14),
#  ('#racism', 14),
#  ('#geoengineering', 14),
#  ('#gerrymandering', 14),
#  ('#telecommunications', 14),
#  ('#communication', 14),
#  ('#greedy', 14),
#  ('#btsarmy', 14),
#  ('#rightsideofhistory', 14),
#  ('#advertising', 14),
#  ('#parenting', 14),
#  ('#mustread', 14),
#  ('#russian', 14),
#  ('#wewontpay', 14),
#  ('#taxcuts', 14),
#  ('#nokxl', 14),
#  ('#success', 14),
#  ('#mepolitics', 14),
#  ('#nbc', 14),
#  ('#keepournetfree', 14),
#  ('#iartg', 14),
#  ('#blogger', 14),
#  ('#alfranken', 14),
#  ('#opensource', 14),
#  ('#control', 14),
#  ('#cio', 14),
#  ('#conservative', 14),
#  ('#teaparty', 14),
#  ('#www', 14),
#  ('#dctech', 14),
#  ('#now', 14),
#  ('#smh', 14),
#  ('#conservativestrong', 14),
#  ('#protestaction', 14),
#  ('#ripple', 14),
#  ('#resistancehttps', 14),
#  ('#velshiruhle', 14),
#  ('#flintwatercrisis', 14),
#  ('#youtubers', 14),
#  ('#libya', 14),
#  ('#mining', 14),
#  ('#saveournet', 14),
#  ('#videogames', 14),
#  ('#internetemergency', 14),
#  ('#spicy', 14),
#  ('#nj', 14),
#  ('#utah', 14),
#  ('#justice', 14),
#  ('#michigan', 14),
#  ('#weresist', 14),
#  ('#igf2017', 14),
#  ('#californiawildfires', 14),
#  ('#savenetneutality', 14),
#  ('#fightforfreeinternet', 14),
#  ('#trumpisnottruepresident', 13),
#  ('#generalstrike', 13),
#  ('#lastweektonight', 13),
#  ('#conpiredwithrussia', 13),
#  ('#liberals', 13),
#  ('#bullshit', 13),
#  ('#bittorrent', 13),
#  ('#factsmatter', 13),
#  ('#comcastpic', 13),
#  ('#lastword', 13),
#  ('#disney', 13),
#  ('#internetaccess', 13),
#  ('#ieedchat', 13),
#  ('#accessibility', 13),
#  ('#bloggers4netneutrality', 13),
#  ('#power', 13),
#  ('#trumpcrimefamily', 13),
#  ('#savenetnuetrality', 13),
#  ('#tuesdaythoughtshttps', 13),
#  ('#nonutnovember', 13),
#  ('#16days', 13),
#  ('#nonprofit', 13),
#  ('#email', 13),
#  ('#swampcabinet', 13),
#  ('#acasabotage', 13),
#  ('#irandeal', 13),
#  ('#dataprotection', 13),
#  ('#transparency', 13),
#  ('#russiaownstrump', 13),
#  ('#saveaca', 13),
#  ('#lobby', 13),
#  ('#please', 13),
#  ('#gov', 13),
#  ('#callyoursenators', 13),
#  ('#tweet', 13),
#  ('#isupportnetneutrality', 13),
#  ('#vtpoli', 13),
#  ('#va10', 13),
#  ('#justiceleague', 13),
#  ('#eeuu', 13),
#  ('#liar', 13),
#  ('#house', 13),
#  ('#lovetheweb', 13),
#  ('#creditunions', 13),
#  ('#newspic', 13),
#  ('#adamknowseverything', 13),
#  ('#thebeat', 13),
#  ('#s', 13),
#  ('#doconservativesloverussia', 13),
#  ('#sarcasm', 13),
#  ('#spreadtheword', 13),
#  ('#amwriting', 13),
#  ('#spotify', 13),
#  ('#foia', 13),
#  ('#fakecomments', 13),
#  ('#countryoverparty', 13),
#  ('#federalcommunicationscommission', 13),
#  ('#fail', 13),
#  ('#itunes', 13),
#  ('#newmusicfriday', 13),
#  ('#tennessee', 13),
#  ('#watch', 13),
#  ('#makeamericagreatagain', 13),
#  ('#obstructionofjustice', 13),
#  ('#ncpol', 13),
#  ('#fightforthenet', 13),
#  ('#caturday', 13),
#  ('#thegameawards', 13),
#  ('#representus', 13),
#  ('#indiawithrahulgandhipic', 13),
#  ...]

# %% [markdown]
# ## Start by tokenizing

# %% [markdown]
# ## Lower case conversion

# %% [markdown]
# ## Punctuation removal

# %% [markdown]
# ## Stop word removal

# %% [markdown]
# ## Lemmatizing

# %%
from collections import Counter
from urllib.parse import urlparse

# %%
entities = []
for txt in mega_df['text']:
    for t in txt.split():
        if t.startswith("http"): #or t.startswith("@") or t.startswith("#") or t.startswith("RT @"):
#             if not t.startswith("http"):
#                 t = t.lower()
            entities.append(t.strip(" :,"))

# %%
entities_combined = []
for txt in mega_df['text']:
    for t in txt.split():
        if t.startswith("http"): #or t.startswith("@") or t.startswith("#") or t.startswith("RT @"):
#             if not t.startswith("http"):
#                 t = t.lower()
#            entities.append(t.strip(" :,"))
            o = urlparse(t)
            url = (o.scheme + '://' + o.netloc).lower()
            entities_combined.append(url)

# %%
entities_counter = Counter(entities)
for entity, freq in entities_counter.most_common()[:1000]:
    print(entity, freq)

# %%
entities_comb_counter = Counter(entities_combined)
for entity, freq in entities_comb_counter.most_common():
    print(entity, freq)

# %%
import spacy
import pandas as pd

nlp = spacy.load('en_core_web_md')

# %%
small_slice = mega_df[:5]

# %%
for text in small_slice['text']:
    doc = nlp(text)
    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)

# %%
import re
from textblob import TextBlob

def clean_tweet(tweet):
    '''
    Utility function to clean tweet text by removing links, special characters
    using simple regex statements.
    '''
    return ' '.join(re.sub("(@\w+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def get_tweet_sentiment(tweet):
    '''
    Utility function to classify sentiment of passed tweet
    using textblob's sentiment method
    '''
    # create TextBlob object of passed tweet text
    analysis = TextBlob(clean_tweet(tweet))
    # set sentiment
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

def compile_tweets(tweet_collection):
    '''
    Main function to parse tweets.
    '''
    # empty list to store parsed tweets
    tweets = []
    # parsing tweets one by one
    for _idx, tweet in tweet_collection.iterrows():
        # empty dictionary to store required params of a tweet
        parsed_tweet = {}
        # saving text of tweet
        parsed_tweet['text'] = tweet.text
        # saving sentiment of tweet
        parsed_tweet['sentiment'] = get_tweet_sentiment(tweet['text'])

        # appending parsed tweet to tweets list
        if tweet['retweets'] > 0:
            # if tweet has retweets, ensure that it is appended only once
            if parsed_tweet not in tweets:
                tweets.append(parsed_tweet)
        else:
            tweets.append(parsed_tweet)

    # return parsed tweets
    return tweets

def main(tweet_collection):
    # calling function to get tweets
    tweets = compile_tweets(tweet_collection)

    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
    # picking neutral tweets from tweets
    neutweets = [tweet for tweet in tweets if tweet['sentiment'] == 'neutral']
    # percentage of neutral tweets
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets)))

    # printing first 5 positive tweets
    print("\n\nPositive tweets:")
    for tweet in ptweets[:10]:
        print(tweet['text'], "\n")

    # printing first 5 negative tweets
    print("\n\nNegative tweets:")
    for tweet in ntweets[:10]:
        print(tweet['text'], "\n")
        
    # printing first 5 negative tweets
    print("\n\nNeutral tweets:")
    for tweet in neutweets[:10]:
        print(tweet['text'], "\n")

# %%
main(small_slice)
# Out:
# Positive tweets percentage: 20.833333333333332 %
# Negative tweets percentage: 22.916666666666668 %
# Neutral tweets percentage: 56.25 %
#
#
# Positive tweets:
# A higher price to binge-watch your favourite series on Netflix or listen to a playlist on Spotify.
#
# That, and much more, is what a loss of #netneutrality could mean for Canada: http://ow.ly/jx6z30gR0d5 pic.twitter.com/CvI2QcemcG
#
# #Comcast hints at plan for paid fast lanes after #netneutrality repeal https://buff.ly/2iVWasb
#
# University tech administrator had to email everyone today to remind them #netneutrality  is vital for our research and use of databases. Great, another thing to worry about is how I'm going to complete research papers without access to the fucken primary sources.
#
# If only 10% of your audience can afford the technology, it doesn't matter how amazing your picture quality is. There's no profit producing media in that format.
#
# Remember LaserDisc and Betamax?
#
# That's what paid prioritization after #NetNeutrality is set to do to 4K.
#
# Easy for you to SAY since you're not voting in Alabama. Now, do something about things you can do something about. Stop the #TaxScamBill Hold hearings to determine what can be done to preserve #NetNeutrality Reauthorize #CHIP
#
# #NETNEUTRALITY  Is pretty much Communism for the internet. It means you cant pay more for faster internet. The bill also limits bandwidth. THE GOVT will regulate who gets bandwidth NOT the market.#NOTONETNEUTRALITY
#
# BREAKING:
# The FCC (Federal Cookie Commission) is going to hand over full control to corporate giants like @ChipsAhoy and @Oreo so that THEY decide how much you pay for chocolate chips, extra filling etc.
#
# #fcc #Netneutrality #snackNeutrality
#
# And, the FCC, ignoring the voices of Americans who wants to keep #NetNeutrality , are volating their "notice and comment" rulemaking process. I cannot help but feel the FCC is a bit corrupted under Trump Administration. pic.twitter.com/JxAH87S0Nx
#
# Listen,everyone.#NetNeutrality is in trouble.The internet will be no longer free at 14th December.Act fast.Share this to http://all.You  can make it difference.https://youtu.be/2IhYNF6_m0Q
#
# This is why #NetNeutrality is so important & Title II https://arstechnica.com/tech-policy/2017/11/comcast-quietly-drops-promise-not-to-charge-tolls-for-internet-fast-lanes/ … @FCC @AjitPaiFCCpic.twitter.com/3wXznVx9Jb
#
#
#
# Negative tweets:
# @SenPatRoberts Killing net neutrality is killing small business. #NetNeutrality
#
# #NetNeutrality affects the internet, which affects everyone. That means that everyone has to chip in and stop FCComcast from changing things for the worse: https://www.battleforthenet.com/
#
# So the @FCC won't let me be
# Or let me be me, so let me see
# They try to shut me down on...
#
# [sorry, page may be viewed by subscribers - please pay $5 to view]
# #NetNeutrality
#
# Repealing #NetNeutrality is just another handout to corporations paid for by average consumers. The freedom and openness of the internet must be preserved.
#
# Revoking #NetNeutrality would further the digital divide across the nation, for everyone from low-income families, to small business owners, to students.
#
# So reports say @Verizon is unfollowing people from the #NetNeutrality tag automatically on #tumblr within 15 minutes or so. Verizon is against net neutrality and owns tumblr so they're trying to squash resistance behind the scenes. How shitty of them. Shame on you #Verizon
#
# What will the end of #netneutrality really mean ? It'll likely strengthen Google, Facebook, and Amazon: http://youtu.be/sqmAkXQ-cQk?a
#
# Internet users outraged by Ajit Pai’s plan to gut #NetNeutrality are planning to protest at #Verizon retail stores:http://s.cgvpn.net/1oW
#
# #NetNeutrality #SaveNetNeutrality
#
# Bad for people, bad for America, bad for everyone but the telecom giants...
#
# Email these three people & ask they vote no!
# Ajit Pai- Ajit.Pai@fcc.gov
# Mike O'Rielly- Mike.ORielly@fcc.gov
# Brendan Carr- Brendan.Carr@fcc.govhttps://www.theverge.com/2017/11/27/16705170/net-neutrality-cyber-monday-fcc-letter?utm_campaign=theverge&utm_content=entry&utm_medium=social&utm_source=twitter …
#
# .@RodneyDavis Just saw one of your form letters that you sent re: #NetNeutrality. It's clear to me that you don't understand how any of it works. Please listen to the tech people when they tell you that losing it would be devastating to the open internet that you claim to want.
#
#
#
# Neutral tweets:
# > #NetNeutrality is an #IoT & #5G issue too -http://klou.tt/1nct5wzrg539f
#
# Call the FCC to fight net neutrality repeal! Here's the number for the FCC chairman, and a script: http://bit.ly/2nacw4X  #FCC #internet #netneutrality
#
# #NetNeutrality pic.twitter.com/YWPXWhbEKW
